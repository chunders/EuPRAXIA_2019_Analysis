# %%
import numpy as np
from scipy.io import loadmat, savemat
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
from imageio import imread
from postPlasmaDiagnostics import img2spec
import os
calFile = r'Z:\2019 EuPRAXIA\OrielMysteryGrating_lambda.mat'

specCal = loadmat(calFile)
#matplotlib.rcsetup.interactive_bk
matplotlib.rcsetup.non_interactive_bk
#matplotlib.rcsetup.all_backends
# Out:
# ['agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
plt.figure()
imgFile = r'Z:\2019 EuPRAXIA\PostPlasmaSpec\20191126_HgAr_mystery_c200.tif'
l,S_l = img2spec(imgFile)
plt.plot(l,S_l/np.max(S_l))

imgFile = r'Z:\2019 EuPRAXIA\PostPlasmaSpec\20191126_HgAr_mystery_c190.tif'
l2,S_l2 = img2spec(imgFile)
plt.plot(l2-40,S_l2/np.max(S_l2))

calFile = r'Z:\2019 EuPRAXIA\OrielMysteryGrating_lambda_20191128.mat'
specCal = {'lambdaAxis': l2-80}
savemat(calFile,specCal)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
calFile = r'Z:\2019 EuPRAXIA\OrielMysteryGrating_lambda_20191127.mat'
imgFile = r'Z:\2019 EuPRAXIA\2019-11-25\PostPlasmaSpectrometer\20191125_mystery_HgAr_c310nm.tif'
l,S_l = img2spec(imgFile)
plt.plot(l,S_l/np.max(S_l))

imgFile = r'Z:\2019 EuPRAXIA\PostPlasmaSpec\20191126_HgAr_mystery_c200.tif'
l2,S_l2 = img2spec(imgFile,calFile)
plt.plot(l2,S_l2/np.max(S_l2))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
logFile = r'Z:\2019 EuPRAXIA\2019-11-26\Untitled1.log'
diagList = ['PostPlasmaSpectrometer']
from livePlotting import continuousPlotting_spectrometer,getLastFileName
from postPlasmaDiagnostics import img2spec
import time
expPath = r'Z:\2019 EuPRAXIA'
oldFilePath = ''
from livePlotting import getLastFileName
from postPlasmaDiagnostics import img2spec
plt.figure()
while True:
    filePathList = getLastFileName(logFile,expPath,['PostPlasmaSpectrometer'])
    if len(filePathList)==1:
        if filePathList[0]==oldFilePath:
            time.sleep(2)
        elif 'fail' not in filePathList[0]:
            l,S_l = img2spec(filePathList[0])
            oldFilePath = filePathList[0]
            plt.plot(l,S_l)
            time.sleep(2)

# %%
from scipy.io import loadmat
from imageio import imread
calFile = r'Z:\2019 EuPRAXIA\OrielMysteryGrating_lambda.mat'

specCal = loadmat(calFile)
l= specCal['lambdaAxis'].flatten()

# %%
filePath =r'Z:\2019 EuPRAXIA\2019-11-26\0001\PostPlasmaSpectrometer\0001_0042_PostPlasmaSpectrometer.tif'
img = imread(filePath)
plt.figure()
plt.plt(specCal['lambdaAxis'])

# %%
os.path.split(filePathList[0])[1]

# %%
np.mean(np.diff(l))
# Out:
# C:\Users\laser\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\laser\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
np.mean(np.diff(np.flip(l)))
# Out:
# 0.2873950097213223

# %%
img = imread(filePath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9f70fba6b028> in <module>
# ----> 1 df = pd.csv_read(r'Z:\2019 EuPRAXIA\2019-11-15\Untitled.log')
#
# NameError: name 'pd' is not defined
